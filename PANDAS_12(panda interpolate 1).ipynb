# %%
import pandas as pd

# %%
df=pd.read_csv("student_results.csv")
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4            11                       2
# 5        1006     11         10            12                       4
# 6        1007     12          4             6                       5
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       3
# 9        1010     12          6             9                       4
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 1          80
# 2                 1          60
# 3                 2          45
# ...

# %%
df.interpolate()
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0      1001.0     10          2      9.000000                       3
# 1      1002.0     10          6      8.000000                       2
# 2      1003.0     10          3      8.000000                       2
# 3      1004.0     11          0     10.000000                       1
# 4      1005.0     11          4      8.666667                       2
# 5      1006.0     11         10      7.333333                       0
# 6      1007.0     12          4      6.000000                       0
# 7      1008.0     12         10      6.000000                       2
# 8      1009.0     12          2      8.000000                       2
# 9      1010.0     12          6      9.000000                       1
#
#    Mobile Games hrs  Percantege
# 0              5.00          50
# 1              0.00          80
# 2              4.00          60
# 3              5.00          45
# ...

# %%
df.interpolate(method='linear')
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0      1001.0     10          2      9.000000                       3
# 1      1002.0     10          6      8.000000                       2
# 2      1003.0     10          3      8.000000                       2
# 3      1004.0     11          0     10.000000                       1
# 4      1005.0     11          4      8.666667                       2
# 5      1006.0     11         10      7.333333                       0
# 6      1007.0     12          4      6.000000                       0
# 7      1008.0     12         10      6.000000                       2
# 8      1009.0     12          2      8.000000                       2
# 9      1010.0     12          6      9.000000                       1
#
#    Mobile Games hrs  Percantege
# 0              5.00          50
# 1              0.00          80
# 2              4.00          60
# 3              5.00          45
# ...

# %%
df=pd.read_csv("student_results.csv")
df
# Out:
#        Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0  11/12/99      1001.0     10          2           9.0
# 1  12/12/99      1002.0     10          6           8.0
# 2  13/12/99         NaN     10          3           8.0
# 3  14/12/99         NaN     11          0          10.0
# 4       NaN      1005.0     11          4           NaN
# 5       NaN         NaN     11         10           NaN
# 6       NaN      1007.0     12          4           6.0
# 7       NaN      1008.0     12         10           6.0
# 8       NaN      1009.0     12          2           8.0
# 9       NaN      1010.0     12          6           9.0
#
#    Social Media usage hrs  Mobile Games hrs  Percantege
# 0                       3               5.0          50
# 1                       2               0.0          80
# 2                       2               4.0          60
# 3                       1               5.0          45
# 4                       2               NaN          75
# ...

# %%
df.interpolate(method='time')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.interpolate(method='time')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:11877, in DataFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   11865 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "method"])
# ...

# %%
type(df.Date[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8604\730087669.py in ?()
# ----> 1 type(df.Date[0])
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Date'

# %%
df=pd.read_csv("student_results.csv",parse_dates=['Date'])
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df=pd.read_csv("student_results.csv",parse_dates=['Date'])
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
# ...

# %%
type(df.Date[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8604\730087669.py in ?()
# ----> 1 type(df.Date[0])
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Date'

# %%
df=pd.read_csv("student_results.csv",parse_dates=['Date'],index_col=['Date'])
df
# Out:
#             Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 1999-11-12      1001.0     10          2           9.0
# 1999-12-12      1002.0     10          6           8.0
# 1999-12-13         NaN     10          3           8.0
# 1999-12-14         NaN     11          0          10.0
# 1999-12-16      1005.0     11          4           NaN
# 1999-12-17         NaN     11         10           NaN
# 1999-12-18      1007.0     12          4           6.0
# 1999-12-19      1008.0     12         10           6.0
# 1999-12-20      1009.0     12          2           8.0
# 1999-12-21      1010.0     12          6           9.0
#
#             Social Media usage hrs  Mobile Games hrs  Percantege
# Date
# 1999-11-12                       3               5.0          50
# 1999-12-12                       2               0.0          80
# 1999-12-13                       2               4.0          60
# 1999-12-14                       1               5.0          45
# ...

# %%
df.interpolate(method='time')
# Out:
#             Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 1999-11-12     1001.00     10          2           9.0
# 1999-12-12     1002.00     10          6           8.0
# 1999-12-13     1002.75     10          3           8.0
# 1999-12-14     1003.50     11          0          10.0
# 1999-12-16     1005.00     11          4           8.0
# 1999-12-17     1006.00     11         10           7.0
# 1999-12-18     1007.00     12          4           6.0
# 1999-12-19     1008.00     12         10           6.0
# 1999-12-20     1009.00     12          2           8.0
# 1999-12-21     1010.00     12          6           9.0
#
#             Social Media usage hrs  Mobile Games hrs  Percantege
# Date
# 1999-11-12                       3               5.0          50
# 1999-12-12                       2               0.0          80
# 1999-12-13                       2               4.0          60
# 1999-12-14                       1               5.0          45
# ...

# %%
df.interpolate(method='index')
# Out:
#             Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 1999-11-12     1001.00     10          2           9.0
# 1999-12-12     1002.00     10          6           8.0
# 1999-12-13     1002.75     10          3           8.0
# 1999-12-14     1003.50     11          0          10.0
# 1999-12-16     1005.00     11          4           8.0
# 1999-12-17     1006.00     11         10           7.0
# 1999-12-18     1007.00     12          4           6.0
# 1999-12-19     1008.00     12         10           6.0
# 1999-12-20     1009.00     12          2           8.0
# 1999-12-21     1010.00     12          6           9.0
#
#             Social Media usage hrs  Mobile Games hrs  Percantege
# Date
# 1999-11-12                       3               5.0          50
# 1999-12-12                       2               0.0          80
# 1999-12-13                       2               4.0          60
# 1999-12-14                       1               5.0          45
# ...

# %%
df=pd.read_csv("student_results.csv",index_col='Class')
df
# Out:
#        Student ID  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Class
# 10         1001.0          2           9.0                       3
# 10         1002.0          6           8.0                       2
# 10            NaN          3           8.0                       2
# 11            NaN          0          10.0                       1
# 11         1005.0          4           NaN                       2
# 11            NaN         10           NaN                       0
# 12         1007.0          4           6.0                       0
# 12         1008.0         10           6.0                       2
# 12         1009.0          2           8.0                       2
# 12         1010.0          6           9.0                       1
#
#        Mobile Games hrs  Percantege
# Class
# 10                  5.0          50
# 10                  0.0          80
# 10                  4.0          60
# 11                  5.0          45
# ...

# %%
df.interpolate(method='index')
# Out:
#        Student ID  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Class
# 10         1001.0          2           9.0                       3
# 10         1002.0          6           8.0                       2
# 10         1002.0          3           8.0                       2
# 11         1005.0          0          10.0                       1
# 11         1005.0          4          10.0                       2
# 11         1005.0         10          10.0                       0
# 12         1007.0          4           6.0                       0
# 12         1008.0         10           6.0                       2
# 12         1009.0          2           8.0                       2
# 12         1010.0          6           9.0                       1
#
#        Mobile Games hrs  Percantege
# Class
# 10                  5.0          50
# 10                  0.0          80
# 10                  4.0          60
# 11                  5.0          45
# ...

# %%
df.interpolate(method="nearest")
# Out:
#        Student ID  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Class
# 10         1001.0          2           9.0                       3
# 10         1002.0          6           8.0                       2
# 10         1001.0          3           8.0                       2
# 11         1005.0          0          10.0                       1
# 11         1005.0          4          10.0                       2
# 11         1005.0         10          10.0                       0
# 12         1007.0          4           6.0                       0
# 12         1008.0         10           6.0                       2
# 12         1009.0          2           8.0                       2
# 12         1010.0          6           9.0                       1
#
#        Mobile Games hrs  Percantege
# Class
# 10                  5.0          50
# 10                  0.0          80
# 10                  4.0          60
# 11                  5.0          45
# ...

# %%
df=pd.read_csv("student_results.csv")
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0      1001.0     10          2           9.0                       3
# 1      1002.0     10          6           8.0                       2
# 2         NaN     10          3           8.0                       2
# 3         NaN     11          0          10.0                       1
# 4      1005.0     11          4           NaN                       2
# 5         NaN     11         10           NaN                       0
# 6      1007.0     12          4           6.0                       0
# 7      1008.0     12         10           6.0                       2
# 8      1009.0     12          2           8.0                       2
# 9      1010.0     12          6           9.0                       1
#
#    Mobile Games hrs  Percantege
# 0               5.0          50
# 1               0.0          80
# 2               4.0          60
# 3               5.0          45
# ...

# %%
df.interpolate(method='polynomial',order=1) #according to polynomial equation of order 1 nan value are filled
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0      1001.0     10          2      9.000000                       3
# 1      1002.0     10          6      8.000000                       2
# 2      1003.0     10          3      8.000000                       2
# 3      1004.0     11          0     10.000000                       1
# 4      1005.0     11          4      8.666667                       2
# 5      1006.0     11         10      7.333333                       0
# 6      1007.0     12          4      6.000000                       0
# 7      1008.0     12         10      6.000000                       2
# 8      1009.0     12          2      8.000000                       2
# 9      1010.0     12          6      9.000000                       1
#
#    Mobile Games hrs  Percantege
# 0              5.00          50
# 1              0.00          80
# 2              4.00          60
# 3              5.00          45
# ...

# %%
df.interpolate(method='polynomial',order=2) #according to polynomial equation of order 2 nan value are filled
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0      1001.0     10          2      9.000000                       3
# 1      1002.0     10          6      8.000000                       2
# 2      1003.0     10          3      8.000000                       2
# 3      1004.0     11          0     10.000000                       1
# 4      1005.0     11          4      9.913371                       2
# 5      1006.0     11         10      7.533997                       0
# 6      1007.0     12          4      6.000000                       0
# 7      1008.0     12         10      6.000000                       2
# 8      1009.0     12          2      8.000000                       2
# 9      1010.0     12          6      9.000000                       1
#
#    Mobile Games hrs  Percantege
# 0          5.000000          50
# 1          0.000000          80
# 2          4.000000          60
# 3          5.000000          45
# ...

# %%
df.interpolate(method='spline',order=1) #according to a rectangular key filling of order 1 nan value are filled
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0      1001.0     10          2      9.000000                       3
# 1      1002.0     10          6      8.000000                       2
# 2      1003.0     10          3      8.000000                       2
# 3      1004.0     11          0     10.000000                       1
# 4      1005.0     11          4      7.590435                       2
# 5      1006.0     11         10      7.237035                       0
# 6      1007.0     12          4      6.000000                       0
# 7      1008.0     12         10      6.000000                       2
# 8      1009.0     12          2      8.000000                       2
# 9      1010.0     12          6      9.000000                       1
#
#    Mobile Games hrs  Percantege
# 0          5.000000          50
# 1          0.000000          80
# 2          4.000000          60
# 3          5.000000          45
# ...
